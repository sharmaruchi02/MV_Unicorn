# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Unicorn_Companies_edit.csv",parse_dates=['Date Joined','Year Founded'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   datetime64[ns]
#  8   Funding           1062 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](2), object(8)
# memory usage: 84.0+ KB

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent Year Founded Funding  \
# 0        Beijing          China           Asia   2012-01-01     $8B
# 1      Hawthorne  United States  North America   2002-01-01     $7B
# 2       Shenzhen          China           Asia   2008-01-01     $2B
# 3  San Francisco  United States  North America   2010-01-01     $2B
# 4      Stockholm         Sweden         Europe   2005-01-01     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
df.insert(2,"Val_B_M",df['Valuation'].str[-1])

# %%
df['Valuation'] = df['Valuation'].str.extract('(\d+)').astype(float)

# %%
df['Valuation']
# Out:
# 0       180.0
# 1       100.0
# 2       100.0
# 3        95.0
# 4        46.0
#         ...
# 1069      1.0
# 1070      1.0
# 1071      1.0
# 1072      1.0
# 1073      1.0
# Name: Valuation, Length: 1074, dtype: float64

# %%
df['Valuation'] = df['Valuation'] * 1000000000

# %%
df.insert(10,"fund_B_M",df['Funding'].str[-1])

# %%
print(type(df['Val_B_M']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['Funding'] = df['Funding'].str.extract('(\d+)')

# %%
df['Valuation']
# Out:
# 0       1.800000e+11
# 1       1.000000e+11
# 2       1.000000e+11
# 3       9.500000e+10
# 4       4.600000e+10
#             ...
# 1069    1.000000e+09
# 1070    1.000000e+09
# 1071    1.000000e+09
# 1072    1.000000e+09
# 1073    1.000000e+09
# Name: Valuation, Length: 1074, dtype: float64

# %%
df.head(500)
# Out:
#        Company   Valuation Val_B_M Date Joined  \
# 0    Bytedance  -388626432       B  2017-04-07
# 1       SpaceX  1215752192       B  2012-12-01
# 2        SHEIN  1215752192       B  2018-07-03
# 3       Stripe   510719488       B  2014-01-23
# 4       Klarna -1244640256       B  2011-12-12
# ..         ...         ...     ...         ...
# 495     Spinny  2000000000       B  2021-11-24
# 496    Trulioo  2000000000       B  2021-06-07
# 497       Zume  2000000000       B  2018-11-01
# 498     AIWAYS  2000000000       B  2018-04-16
# 499      Bitso  2000000000       B  2021-05-05
#
#                             Industry           City        Country  \
# 0            Artificial intelligence        Beijing          China
# 1                              Other      Hawthorne  United States
# 2    E-commerce & direct-to-consumer       Shenzhen          China
# 3                            Fintech  San Francisco  United States
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   int32
#  2   Val_B_M           1074 non-null   object
#  3   Date Joined       1074 non-null   datetime64[ns]
#  4   Industry          1074 non-null   object
#  5   City              1058 non-null   object
#  6   Country           1074 non-null   object
#  7   Continent         1074 non-null   object
#  8   Year Founded      1074 non-null   datetime64[ns]
#  9   Funding           1062 non-null   object
#  10  fund_B_M          1062 non-null   object
#  11  Select Investors  1073 non-null   object
# dtypes: datetime64[ns](2), int32(1), object(9)
# memory usage: 96.6+ KB

# %%
df.to_csv('Unicorn_Companies_edited.csv')
